# %%
import numpy as np
import pylas

# %%
file = pylas.read("./LiDAR/Mar16_train.laz")
file.header.point_count
# Out:
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 file = pylas.read("./LiDAR/Mar16_train.laz")
#       2 file.header.point_count
#
# File d:\Уник\ВКР\venv\Lib\site-packages\pylas\lib.py:94, in read_las(source, closefd)
#      70 """ Entry point for reading las data in pylas
#      71
#      72 Reads the whole file into memory.
#    (...)     91     The object you can interact with to get access to the LAS points & VLRs
#      92 """
#      93 with open_las(source, closefd=closefd) as reader:
# ---> 94     return reader.read()
#
# File d:\Уник\ВКР\venv\Lib\site-packages\pylas\lasreader.py:64, in LasReader.read(self)
#      61 self.stream.seek(self.start_pos + self.header.offset_to_point_data)
#      63 try:
# ---> 64     points = self._read_points(vlrs)
#      65 except errors.LazError as e:
# ...

# %%
file.point

# %%
with pylas.open("./LiDAR/Mar16_train.laz") as f:
    print(np.unique(f.classification))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 with pylas.open("./LiDAR/Mar16_train.laz") as f:
# ----> 2     print(np.unique(f.classification))
#
# AttributeError: 'LasReader' object has no attribute 'classification'
